# %%
import cv2
from keras.models import load_model
import numpy as np

from utils.datasets import get_labels
from utils.inference import load_image
from utils.preprocessor import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
image_path = 'TrainPositive01-1e343.jpgface4.bmp'
emotion_model_path = '../trained_models/emotion_models/fer2013_mini_XCEPTION.102-0.66.hdf5'

emotion_labels = get_labels('fer2013')
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
from os import listdir
from os.path import isfile, join
negative_names = [f for f in listdir('../imgs/train_crops/negative/') if isfile(join('../imgs/train_crops/negative/', f))]

# %%
emotion_target_size = emotion_classifier.input_shape[1:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8991721d2532> in <module>()
# ----> 1 emotion_target_size = emotion_classifier.input_shape[1:3]
#
# NameError: name 'emotion_classifier' is not defined

# %%
path = '../imgs/train_crops/negative/'
fully = False
for image_path in negative_names:
    gray_image = load_image(path + image_path, grayscale=True)
    gray_image = np.squeeze(gray_image)
    gray_image = gray_image.astype('uint8')
    
    gray_face = gray_image
    
    gray_face = cv2.resize(gray_face, (emotion_target_size))
    
    try:
        gray_face = cv2.resize(gray_face, (emotion_target_size))
    except:
        print('exception ignored')
        
    gray_face = preprocess_input(gray_face, True)
    gray_face = np.expand_dims(gray_face, 0)
    gray_face = np.expand_dims(gray_face, -1)
    
    with open('negative.txt', 'a') as file:
        file.write(str(image_path) + ' ')
        for prob in emotion_classifier.predict(gray_face)[0]:
            file.write( str(prob) + ' ')
        file.write('\n')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-69-1feaec5e180f> in <module>()
#       2 fully = False
#       3 for image_path in negative_names:
# ----> 4     gray_image = load_image(path + image_path, grayscale=True)
#       5     gray_image = np.squeeze(gray_image)
#       6     gray_image = gray_image.astype('uint8')
#
# ~/Документы/Education/Diplom/face_classification/src/utils/inference.py in load_image(image_path, grayscale, target_size)
#       5
#       6 def load_image(image_path, grayscale=False, target_size=None):
# ----> 7     pil_image = image.load_img(image_path, grayscale, target_size)
#       8     return image.img_to_array(pil_image)
#       9
#
# ~/.local/lib/python3.5/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, target_size)
#     320         raise ImportError('Could not import PIL.Image. '
# ...

# %%
emotion_classifier.compile(optimizer='adam', loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
emotion_classifier.outputs = [emotion_classifier.layers[-1].output]

# %%
emotion_classifier.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 64, 64, 1)     0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 62, 62, 8)     72          input_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 62, 62, 8)     32          conv2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 62, 62, 8)     0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
a = emotion_classifier.predict(gray_face)[0]

# %%
b = emotion_classifier.predict(gray_face)[0]

# %%
np.mean([a,b],axis=1)
# Out:
# array([[[-0.34585798, -2.58869243,  2.97005677, -2.2863574 ,  1.73353219,
#          -1.35756862, -0.66594261],
#         [ 0.52094841, -7.04632568,  1.08629906,  0.6210779 ,  1.99700212,
#          -3.47163248,  0.36815912],
#         [ 0.24316537, -8.65553951,  1.2047478 , -0.16036171,  2.97974372,
#          -1.88010764,  0.53173423],
#         [ 0.85853004, -7.83809376,  2.92880583, -2.30771184,  1.20799315,
#          -1.50956631, -0.82742327]],
#
#        [[ 0.9148863 , -0.98932177, -0.39567026,  0.85472566, -0.07092805,
#          -0.27454853,  0.07196015],
#         [-2.24910688, -3.17330933,  1.82460916,  1.28809237,  3.0585506 ,
#           0.92938805, -1.39416087],
#         [ 0.111278  , -8.43431664,  2.05992556,  1.12912369,  3.33367443,
#          -0.66216564,  0.85873097],
#         [ 2.67182565, -7.01409912, -1.88117814,  2.41271925,  0.5165363 ,
#          -3.02734566,  3.81089067]]], dtype=float32)

# %%
emotion_classifier.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 64, 64, 1)     0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 62, 62, 8)     72          input_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 62, 62, 8)     32          conv2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 62, 62, 8)     0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
emotion_classifier.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 64, 64, 1)     0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 62, 62, 8)     72          input_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 62, 62, 8)     32          conv2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 62, 62, 8)     0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
cl2 = emotion_classifier.layers.pop()

# %%
emotion_classifier.compile()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d34aad6b58c5> in <module>()
# ----> 1 emotion_classifier.compile()
#
# NameError: name 'emotion_classifier' is not defined

# %%
emotion_classifier.predict(gray_face)
# Out:
# array([[ 0.27603233,  0.00120303,  0.14926954,  0.00374259,  0.24663557,
#          0.04497306,  0.27814388]], dtype=float32)
